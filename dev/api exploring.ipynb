# %%
import requests
from datetime import datetime

# %%
api_url = "https://www.bikereg.com/api/search"
response = requests.get(api_url)

# %%
response
# Out:
# <Response [200]>

# %%
json_response = response.json()

# %%
type(json_response)
# Out:
# dict

# %%
print(json_response)
# Out:
# {'CompletionTime': 0, 'MatchingEvents': [{'Categories': [{'CategoryDates': ['/Date(1697428800000-0400)/', '/Date(1697515200000-0400)/', '/Date(1697601600000-0400)/', '/Date(1697688000000-0400)/', '/Date(1697774400000-0400)/', '/Date(1697860800000-0400)/', '/Date(1697947200000-0400)/', '/Date(1698033600000-0400)/', '/Date(1698120000000-0400)/', '/Date(1698206400000-0400)/', '/Date(1698292800000-0400)/', '/Date(1698379200000-0400)/', '/Date(1698465600000-0400)/'], 'CategoryID': 753385, 'CategoryName': 'Yes, I am an overall points winner by a category', 'Distance': '   ', 'EntryFee': 0.0, 'EntryFees': [{'EntryFee': 0.0}], 'FieldLimit': 0, 'StartTime': '23:59:00'}], 'CoverPhoto': 'https://d36gb93zszu20a.cloudfront.net/BR/VirtualImages/EventLogos//cr-3320b493-213f-4a0a-af8a-99e1198e35c4.jpg', 'Distance': 0, 'EventAddress': '23333 Scotts Flat Rd, Nevada City, CA 95959', 'EventCity': 'Nevada City', 'EventDate': '/Date(1697428800000-0400)/', 'EventEndDate': '/Date(1698465600000-0400)/', 'EventId': 62779, 'EventLogo': None, 'EventName': 'Winners Jersey Order - CA Dirt MTB Series Overall Points by Category', 'EventNotes': '<p style="text-align: center">Congratulations! &nbsp;</p><p style="text-align: center">This is where you order your winners jersey (a red insigna winners stripe) for Winners Jersey Order - CA Dirt MTB Series Overall Points by Category. &nbsp;Jersey is by Voler, made in Grover, California. &nbsp;</p><p style="text-align: center">Please enter your cell no., first and last name and address to receive your jersey by US Postal Service. &nbsp;We will generate mail labels from the address entered.</p><p style="text-align: center">Thank you for racing in the CA Dirt MTB Series!</p><p style="text-align: center">Jet Lowe</p><p style="text-align: center">Event Organizer</p>', 'EventPermalink': 'http://www.BikeReg.com/62779', 'EventState': 'CA', 'EventTypes': ['Special Event'], 'EventUrl': 'http://www.BikeReg.com/winners-jersey-order-ca-dirt-mtb-series-overall-points-by-category', 'EventWebsite': 'https://ybonc.org/events/dirt-classic/', 'EventZip': '95959', 'Latitude': 39.278078, 'Longitude': -120.92224, 'Permit': '', 'PledgeRegUrl': None, 'PresentedBy': 'Youth Bicyclists of Nevada Co. Fdn.', 'RegCloseDate': '/Date(1698390060000-0400)/', 'RegOpenDate': '/Date(1697439660000-0400)/'}, {'Categories': [{'CategoryDates': ['/Date(1698379200000-0400)/'], 'CategoryID': 739146, 'CategoryName': 'RRFCX Clinic and Pre-Ride', 'Distance': '   ', 'EntryFee': 0.0, 'EntryFees': [{'EntryFee': 0.0}], 'FieldLimit': 60, 'StartTime': '15:30:00'}, {'CategoryDates': ['/Date(1698465600000-0400)/'], 'CategoryID': 739090, 'CategoryName': 'Saturday: Junior Men 13-14', 'Distance': '30 minutes', 'EntryFee': 40.0, 'EntryFees': [{'EntryFee': 30.0}, {'EntryFee': 40.0}], 'FieldLimit': 50, 'StartTime': '07:30:00'}, {'CategoryDates': ['/Date(1698465600000-0400)/'], 'CategoryID': 739101, 'CategoryName': 'Saturday: Junior Women 13-14', 'Distance': '30 minutes', 'EntryFee': 40.0, 'EntryFees': [{'EntryFee': 30.0}, {'EntryFee': 40.0}], 'FieldLimit': 50, 'StartTime': '07:30:00'}, {'CategoryDates': ['/Date(1698465600000-0400)/'], 'CategoryID': 739091, 'CategoryName': 'Saturday: Junior Men 11-12', 'Distance': '30 minutes', 'EntryFee': 40.0, 'EntryFees': [{'EntryFee': 30.0}, {'EntryFee': 40.0}], 'FieldLimit': 25, 'StartTime': '07:30:00'}, {'CategoryDates': ['/Date(1698465600000-0400)/'], 'CategoryID': 739102, 'CategoryName': 'Saturday: Junior Women 11-12', 'Distance': '30 minutes', 'EntryFee': 40.0, 'EntryFees': [{'EntryFee': 30.0}, {'EntryFee': 40.0}], 'FieldLimit': 25, 'StartTime': '07:30:00'}, {'CategoryDates': ['/Date(1698465600000-0400)/'], 'CategoryID': 739108, 'CategoryName': 'Saturday: Junior Men 9-10', 'Distance': '30 minutes', 'EntryFee': 40.0, 'EntryFees': [{'EntryFee': 30.0}, {'EntryFee': 40.0}], 'FieldLimit': 25, 'StartTime': '07:30:00'}, {'CategoryDates': ['/Date(1698465600000-0400)/'], 'CategoryID': 739107, 'CategoryName': 'Saturday: Junior Women 9-10', 'Dis ...

# %%
events = json_response["MatchingEvents"]

# %%
events[2]
# Out:
# {'Categories': [{'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 752994,
#    'CategoryName': 'Fly Guys ',
#    'Distance': '   ',
#    'EntryFee': 0.0,
#    'EntryFees': [{'EntryFee': 0.0}],
#    'FieldLimit': 0,
#    'StartTime': '19:30:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 752974,
#    'CategoryName': 'Shreddy Bettie’s ',
#    'Distance': '   ',
#    'EntryFee': 0.0,
#    'EntryFees': [{'EntryFee': 0.0}],
#    'FieldLimit': 0,
#    'StartTime': '19:30:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750764,
#    'CategoryName': 'EBIKE',
#    'Distance': '   ',
#    'EntryFee': 40.0,
#    'EntryFees': [{'EntryFee': 40.0}],
#    'FieldLimit': 0,
#    'StartTime': '14:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750747,
#    'CategoryName': 'Pro Men ',
#    'Distance': '   ',
#    'EntryFee': 40.0,
#    'EntryFees': [{'EntryFee': 40.0}],
#    'FieldLimit': 0,
#    'StartTime': '14:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750748,
#    'CategoryName': 'Pro Women ',
#    'Distance': '   ',
#    'EntryFee': 40.0,
#    'EntryFees': [{'EntryFee': 40.0}],
#    'FieldLimit': 0,
#    'StartTime': '14:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750749,
#    'CategoryName': 'Open Masters Men (40+)',
#    'Distance': '   ',
#    'EntryFee': 40.0,
#    'EntryFees': [{'EntryFee': 40.0}],
#    'FieldLimit': 0,
#    'StartTime': '14:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750750,
#    'CategoryName': 'Open Women Masters (40+) ',
#    'Distance': '   ',
#    'EntryFee': 40.0,
#    'EntryFees': [{'EntryFee': 40.0}],
#    'FieldLimit': 0,
#    'StartTime': '14:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750751,
#    'CategoryName': 'Open Men (18 - 39) ',
#    'Distance': '   ',
#    'EntryFee': 40.0,
#    'EntryFees': [{'EntryFee': 40.0}],
#    'FieldLimit': 0,
#    'StartTime': '14:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750752,
#    'CategoryName': 'Open Women (18 - 39) ',
#    'Distance': '   ',
#    'EntryFee': 40.0,
#    'EntryFees': [{'EntryFee': 40.0}],
#    'FieldLimit': 0,
#    'StartTime': '14:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750753,
#    'CategoryName': 'GROM Boys ( 13-17) ',
#    'Distance': '   ',
#    'EntryFee': 35.0,
#    'EntryFees': [{'EntryFee': 35.0}],
#    'FieldLimit': 0,
#    'StartTime': '14:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750754,
#    'CategoryName': 'GROM Girls ( 13-17) ',
#    'Distance': '   ',
#    'EntryFee': 35.0,
#    'EntryFees': [{'EntryFee': 35.0}],
#    'FieldLimit': 0,
#    'StartTime': '14:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750755,
#    'CategoryName': 'GROM  (12 and under) ',
#    'Distance': '   ',
#    'EntryFee': 35.0,
#    'EntryFees': [{'EntryFee': 35.0}],
#    'FieldLimit': 0,
#    'StartTime': '14:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750765,
#    'CategoryName': 'OPEN MEN ',
#    'Distance': '   ',
#    'EntryFee': 20.0,
#    'EntryFees': [{'EntryFee': 20.0}],
#    'FieldLimit': 150,
#    'StartTime': '09:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750766,
#    'CategoryName': 'OPEN WOMEN',
#    'Distance': '   ',
#    'EntryFee': 20.0,
#    'EntryFees': [{'EntryFee': 20.0}],
#    'FieldLimit': 0,
#    'StartTime': '09:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750757,
#    'CategoryName': 'EBIKE',
#    'Distance': '   ',
#    'EntryFee': 20.0,
#    'EntryFees': [{'EntryFee': 20.0}],
#    'FieldLimit': 0,
#    'StartTime': '09:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750769,
#    'CategoryName': 'SINGLE SPEED',
#    'Distance': '   ',
#    'EntryFee': 20.0,
#    'EntryFees': [{'EntryFee': 20.0}],
#    'FieldLimit': 0,
#    'StartTime': '09:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750770,
#    'CategoryName': 'Junior  BOYS (17 and under) ',
#    'Distance': '   ',
#    'EntryFee': 15.0,
#    'EntryFees': [{'EntryFee': 15.0}],
#    'FieldLimit': 0,
#    'StartTime': '09:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750759,
#    'CategoryName': 'Junior Girls 17and under ',
#    'Distance': '   ',
#    'EntryFee': 15.0,
#    'EntryFees': [{'EntryFee': 15.0}],
#    'FieldLimit': 0,
#    'StartTime': '09:00:00'},
#   {'CategoryDates': ['/Date(1698465600000-0400)/'],
#    'CategoryID': 750763,
#    'CategoryName': 'YOUTH UNDER 12',
#    'Distance': '   ',
#    'EntryFee': 15.0,
#    'EntryFees': [{'EntryFee': 15.0}],
#    'FieldLimit': 0,
#    'StartTime': '09:00:00'},
#   {'CategoryDates': ['/Date(1698379200000-0400)/',
#     '/Date(1698465600000-0400)/',
#     '/Date(1698552000000-0400)/'],
#    'CategoryID': 750745,
#    'CategoryName': 'Friday Night Campsite  ',
#    'Distance': '   ',
#    'EntryFee': 5.0,
#    'EntryFees': [{'EntryFee': 5.0}],
#    'FieldLimit': 0,
#    'StartTime': '15:00:00'},
#   {'CategoryDates': ['/Date(1698379200000-0400)/',
#     '/Date(1698465600000-0400)/',
#     '/Date(1698552000000-0400)/'],
#    'CategoryID': 750746,
#    'CategoryName': 'Saturday Campsite ',
#    'Distance': '   ',
#    'EntryFee': 5.0,
#    'EntryFees': [{'EntryFee': 5.0}],
#    'FieldLimit': 0,
#    'StartTime': '15:00:00'},
#   {'CategoryDates': ['/Date(1698379200000-0400)/',
#     '/Date(1698465600000-0400)/',
#     '/Date(1698552000000-0400)/'],
#    'CategoryID': 750744,
#    'CategoryName': 'Weekend Camping ',
#    'Distance': '   ',
#    'EntryFee': 10.0,
#    'EntryFees': [{'EntryFee': 10.0}],
#    'FieldLimit': 0,
#    'StartTime': '15:00:00'}],
#  'CoverPhoto': None,
#  'Distance': 0,
#  'EventAddress': '21215 Shearer Rd',
#  'EventCity': 'Davidson',
#  'EventDate': '/Date(1698379200000-0400)/',
#  'EventEndDate': '/Date(1698552000000-0400)/',
#  'EventId': 62606,
#  'EventLogo': 'https://d36gb93zszu20a.cloudfront.net/BR/VirtualImages/EventLogos//7b4f3a1e-4611-43bb-9d4a-204a334db406.png',
#  'EventName': 'FISHER FEST 2023',
#  'EventNotes': '<p style="text-align: center"><span style="font-family: Verdana, Geneva, sans-serif; font-size: 22pt">FISHER FEST 2023</span></p><p style="text-align: center"><span style="font-family: Arial, Helvetica, sans-serif; font-size: 14.6666669845581px">Presented By The&nbsp;Tarheel Trailblazers and The Cycle Path&nbsp;</span></p><p style="text-align: center">21215 Shearer Rd, Davidson, NC 28036</p><p style="text-align: center">&nbsp;</p><p style="text-align: center"><span style="font-size: medium">Join us at Cedar Valley Bike Park and Fisher Farm,&nbsp;the Weekend of October 27th-29th for one RAD MTB event unlike any other!&nbsp;</span></p><p style="text-align: center"><span style="font-size: 12pt">Let\'s Ride, Race, and Party all while raising money to support our trails!&nbsp;</span></p><p style="text-align: center">&nbsp;</p><p style="text-align: center"><span style="font-size: 14pt"><span style="font-family: Comic Sans MS, cursive"><strong>What all does Fisher Fest have&nbsp;going on?!</strong></span></span></p><p style="text-align: center">&nbsp;</p><p style="text-align: center"><span style="font-size: 12pt"><strong>FRIDAY</strong></span></p><p style="text-align: center">Come on out Friday afternoon&nbsp;and Pre-Ride for the 4 Spicy Stages of the&nbsp;Enduro that will have stages utilizing Cedar Valley, Fisher Farm and Twisted Sister! &nbsp;</p><p style="text-align: center">We will also have the Fasted in Fisher XC Course set up for pre ride!&nbsp;</p><p style="text-align: center">On Site Primitive camping will be available&nbsp;Friday and Saturday Night, so come on down and set up your tent or RV! Campers will have acess to port a jons and running water is available&nbsp;on site. RVs are welcome but there are no water or power hook ups.&nbsp;</p><p>FRIDAY&nbsp;<br>3pm - &nbsp; &nbsp;Race Courses Taped and open for practice<br>&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;Camping area open for set up<br>SATURDAY&nbsp;<br>8am &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Registration Tent Opens<br>9am &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Fastest in Fisher Racer Meeting&nbsp;<br>9am - 11:30 &nbsp; &nbsp;Fastest in Fisher XC Race&nbsp;<br>9am - 2pm &nbsp; &nbsp; &nbsp;Cedar Valley Open for play and practice&nbsp;<br>12pm - 2pm &nbsp; &nbsp;Trailblazer Grill serving up grub&nbsp;<br>12pm &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;Fisher Farm open for riding&nbsp;<br>12:30pm &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;Fastest in Fisher Awards&nbsp;<br>2pm &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Cedar Valley Enduro Race Meeting&nbsp;<br>2pm - 5pm &nbsp; &nbsp; &nbsp;Cedar Valley Enduro Race&nbsp;<br>6:30 pm &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Haunted trail ride on Helter Skelter&nbsp;<br>7pm &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;A Wicked Jump Jam Party In the woods with Redbull<br>8pm &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; AWARDS AND SWAG GIVEAWAYS</p><p style="text-align: center"><strong>8PM AND BEYOND: MUSIC, SMORES AND &nbsp;BONFIRE!</strong></p><p style="text-align: center"><strong>COSTUMES HIGHLY ENCOURAGED AND RACERS WILL RECEIVE A TIME BONUS FOR RACING IN COSTUME !&nbsp;</strong></p><p style="text-align: center">&nbsp;</p><p style="text-align: center"><span style="font-size: 12pt"><strong>Sunday</strong></span></p><p style="text-align: center"><strong>10:30AM&nbsp;</strong>Dirt Church is in Session&nbsp;</p><p style="text-align: center">Group Sessions and group rides for all skill levels!&nbsp;</p><p style="text-align: center"><strong>1:00 PM PACK IT UP / CLEAN IT UP&nbsp;</strong></p><p style="text-align: center">&nbsp;</p><p style="text-align: center"><strong>CAMPING&nbsp;</strong></p><ul><li>Primitive camping will be avialable&nbsp;on site Friday and Saturday&nbsp;</li><li>Port a jons will be available&nbsp;(no Showers)&nbsp;</li><li>running water available&nbsp;on site&nbsp;</li><li>RVs are welcome (no water or electrici ...
#  'EventPermalink': 'http://www.BikeReg.com/62606',
#  'EventState': 'NC',
#  'EventTypes': ['Recreational', 'Special Event'],
#  'EventUrl': 'http://www.BikeReg.com/fisher-fest',
#  'EventWebsite': 'http://www.tarheeltrailblazers.com',
#  'EventZip': '28036',
#  'Latitude': 35.4889095,
#  'Longitude': -80.8004031,
#  'Permit': '',
#  'PledgeRegUrl': None,
#  'PresentedBy': 'TARHEEL TRAILBLAZERS',
#  'RegCloseDate': '/Date(1698613200000-0400)/',
#  'RegOpenDate': '/Date(1695218400000-0400)/'}

# %%
events[2]["EventEndDate"].timestamp()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /app/dev/api exploring.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f62696b657265675f7365617263682d707974686f6e2d31222c22637764223a22653a5c5c6d795f70726f6a656374735c5c62696b657265675f736561726368227d/app/dev/api%20exploring.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> events[2]["EventEndDate"].timestamp()
#
# AttributeError: 'str' object has no attribute 'timestamp'

# %%
type(events)
# Out:
# list
