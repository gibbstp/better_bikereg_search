# %%
import requests

# %%
api_url_1 = "https://www.bikereg.com/api/search?startpage=0"
api_url_2 = "https://www.bikereg.com/api/search?startpage=1"
json_response_1 = requests.get(api_url_1).json()
json_response_2 = requests.get(api_url_2).json()

events_1 = json_response_1["MatchingEvents"]
events_2 = json_response_2["MatchingEvents"]

print(events_1)
print(events_2)
# Out:
# [{'Categories': [{'CategoryDates': ['/Date(1699938000000-0500)/'], 'CategoryID': 759042, 'CategoryName': 'CX Men Cat4/5 - CX Women Cat 1/2/3/4/5 - Juniors', 'Distance': '30 minutes', 'EntryFee': 20.0, 'EntryFees': [{'EntryFee': 20.0}], 'FieldLimit': 0, 'StartTime': '18:00:00'}, {'CategoryDates': ['/Date(1699938000000-0500)/'], 'CategoryID': 759041, 'CategoryName': 'CX Men Cat 1/2/3', 'Distance': '45 minutes', 'EntryFee': 20.0, 'EntryFees': [{'EntryFee': 20.0}], 'FieldLimit': 0, 'StartTime': '18:40:00'}, {'CategoryDates': ['/Date(1700542800000-0500)/'], 'CategoryID': 759044, 'CategoryName': 'CX Men Cat4/5 - CX Women Cat 1/2/3/4/5 - Juniors', 'Distance': '30 minutes', 'EntryFee': 20.0, 'EntryFees': [{'EntryFee': 20.0}], 'FieldLimit': 0, 'StartTime': '18:00:00'}, {'CategoryDates': ['/Date(1700542800000-0500)/'], 'CategoryID': 759043, 'CategoryName': 'CX Men Cat 1/2/3', 'Distance': '45 minutes', 'EntryFee': 20.0, 'EntryFees': [{'EntryFee': 20.0}], 'FieldLimit': 0, 'StartTime': '18:40:00'
# ...

# %%
len(events_1)
# Out:
# 100

# %%
len(events_2)
# Out:
# 100

# %%
both_events = events_1.extend(events_2)

# %%
def testing(lst_1, lst_2):
    
    return lst_1.extend(lst_2)

# %%
test_list = testing(events_1, events_2)
